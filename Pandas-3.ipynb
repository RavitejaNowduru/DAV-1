# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: C:\Users\ravit\Scaler\Data Analytics and Visualizations(DAV-1)\directors.csv
#
#   0%|          | 0.00/65.4k [00:00<?, ?B/s]
# 100%|##########| 65.4k/65.4k [00:00<00:00, 653kB/s]
# 100%|##########| 65.4k/65.4k [00:00<00:00, 653kB/s]

# %%
import pandas as pd

# %%
directors = pd.read_csv(r'C:\Users\ravit\Scaler\Data Analytics and Visualizations(DAV-1)\directors.csv')

# %%
directors
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
directors.drop(columns= 'Unnamed: 0', inplace = True)

# %%
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: C:\Users\ravit\Scaler\Data Analytics and Visualizations(DAV-1)\movies.csv
#
#   0%|          | 0.00/112k [00:00<?, ?B/s]
# 100%|##########| 112k/112k [00:00<00:00, 1.12MB/s]
# 100%|##########| 112k/112k [00:00<00:00, 1.12MB/s]

# %%
movies = pd.read_csv(r'C:\Users\ravit\Scaler\Data Analytics and Visualizations(DAV-1)\movies.csv')
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movies.drop(columns = 'Unnamed: 0', inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 movies.drop(columns = 'Unnamed: 0', inplace= True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
users = pd.DataFrame({"userid":[1,2,3],"name":["Ichigo","Santosh","Avinash"]})
users
# Out:
#    userid     name
# 0       1   Ichigo
# 1       2  Santosh
# 2       3  Avinash

# %%
msgs = pd.DataFrame({"userid":[1,1,2,4],"msg":["hmm","acha","theek hain","nice"]})
msgs
# Out:
#    userid         msg
# 0       1         hmm
# 1       1        acha
# 2       2  theek hain
# 3       4        nice

# %%
pd.concat([users,msgs])
# Out:
#    userid     name         msg
# 0       1   Ichigo         NaN
# 1       2  Santosh         NaN
# 2       3  Avinash         NaN
# 0       1      NaN         hmm
# 1       1      NaN        acha
# 2       2      NaN  theek hain
# 3       4      NaN        nice

# %%
pd.concat([users,msgs], ignore_index = True)
# Out:
#    userid     name         msg
# 0       1   Ichigo         NaN
# 1       2  Santosh         NaN
# 2       3  Avinash         NaN
# 3       1      NaN         hmm
# 4       1      NaN        acha
# 5       2      NaN  theek hain
# 6       4      NaN        nice

# %%
pd.concat([users,msgs], axis = 1)
# Out:
#    userid     name  userid         msg
# 0     1.0   Ichigo       1         hmm
# 1     2.0  Santosh       1        acha
# 2     3.0  Avinash       2  theek hain
# 3     NaN      NaN       4        nice

# %%
pd.merge(users,msgs) #Inner Join of SQL is merge
# Out:
#    userid     name         msg
# 0       1   Ichigo         hmm
# 1       1   Ichigo        acha
# 2       2  Santosh  theek hain

# %%
pd.merge(users,msgs, on = 'userid')
# Out:
#    userid     name         msg
# 0       1   Ichigo         hmm
# 1       1   Ichigo        acha
# 2       2  Santosh  theek hain

# %%
pd.merge(users,msgs, on = 'userid', how = 'left')
# Out:
#    userid     name         msg
# 0       1   Ichigo         hmm
# 1       1   Ichigo        acha
# 2       2  Santosh  theek hain
# 3       3  Avinash         NaN

# %%
pd.merge(users,msgs, on = 'userid', how = 'right')
# Out:
#    userid     name         msg
# 0       1   Ichigo         hmm
# 1       1   Ichigo        acha
# 2       2  Santosh  theek hain
# 3       4      NaN        nice

# %%
pd.merge(users,msgs, on = 'userid', how = 'outer')
# Out:
#    userid     name         msg
# 0       1   Ichigo         hmm
# 1       1   Ichigo        acha
# 2       2  Santosh  theek hain
# 3       3  Avinash         NaN
# 4       4      NaN        nice

# %%
users.rename(columns = {'userid':'id'}, inplace = True)

# %%
users
# Out:
#    id     name
# 0   1   Ichigo
# 1   2  Santosh
# 2   3  Avinash

# %%
msgs
# Out:
#    userid         msg
# 0       1         hmm
# 1       1        acha
# 2       2  theek hain
# 3       4        nice

# %%
merged = users.merge(msgs, left_on = 'id', right_on = 'userid')
merged
# Out:
#    id     name  userid         msg
# 0   1   Ichigo       1         hmm
# 1   1   Ichigo       1        acha
# 2   2  Santosh       2  theek hain

# %%
merged.drop(columns= 'userid')
# Out:
#    id     name         msg
# 0   1   Ichigo         hmm
# 1   1   Ichigo        acha
# 2   2  Santosh  theek hain

# %%
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies.shape
# Out:
# (1465, 11)

# %%
movies['director_id'].nunique()
# Out:
# 199

# %%
directors['id'].nunique()
# Out:
# 2349

# %% [markdown]
# isin function

# %%
movies["director_id"].isin(directors["id"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: director_id, Length: 1465, dtype: bool

# %%
pd.Series([2000,3000,4000]).isin([2000,3000])
# Out:
# 0     True
# 1     True
# 2    False
# dtype: bool

# %%
import numpy as np
np.all(pd.Series([2000,3000,4000]).isin([2000,3000]))
# Out:
# False

# %%
import numpy as np
np.any(pd.Series([2000,3000,4000]).isin([2000,3000]))
# Out:
# True

# %%
np.all(movies["director_id"].isin(directors["id"])) 
# All the directors those are in movies dataframe are present in directors dataframe. But vice versa is not applicable
# Out:
# True

# %%
np.all(directors["id"].isin(movies["director_id"]))
# Out:
# False

# %%
data = pd.merge(movies, directors, left_on = 'director_id', right_on = 'id', how = 'inner') 
#Caarried out Inner join as np.all from movies in directors is True

# %%
data
# Out:
#        id_x     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
# ...     ...        ...         ...         ...                         ...
# 1460  46859          0          14    25288872                 Enough Said
# 1461  47023    6500000          11    13368437          Friends with Money
# 1462  47524    3000000           5           0                 Please Give
# 1463  47962          0           0           0         Walking and Talking
# 1464  48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
data.drop(columns = ['director_id', 'id_y'], inplace = True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
# ...     ...        ...         ...         ...                         ...
# 1460  46859          0          14    25288872                 Enough Said
# 1461  47023    6500000          11    13368437          Friends with Money
# 1462  47524    3000000           5           0                 Please Give
# 1463  47962          0           0           0         Walking and Talking
# 1464  48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
data.rename(columns={'id':'movie_id'}, inplace = True)

# %%
data
# Out:
#       movie_id     budget  popularity     revenue                       title  \
# 0        43597  237000000         150  2787965087                      Avatar
# 1        43622  200000000         100  1845034188                     Titanic
# 2        43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3        43879  115000000          38   378882411                   True Lies
# 4        44184   70000000          24    90000098                   The Abyss
# ...        ...        ...         ...         ...                         ...
# 1460     46859          0          14    25288872                 Enough Said
# 1461     47023    6500000          11    13368437          Friends with Money
# 1462     47524    3000000           5           0                 Please Give
# 1463     47962          0           0           0         Walking and Talking
# 1464     48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
data.shape
# Out:
# (1465, 12)

# %%
data.nunique()
# Out:
# movie_id         1465
# budget            201
# popularity        128
# revenue          1267
# title            1465
# vote_average       51
# vote_count       1019
# year               41
# month              12
# day                 7
# director_name     199
# gender              2
# dtype: int64

# %%
data.describe()
# Out:
#            movie_id        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count         year
# count   1465.000000  1465.000000
# mean    1146.396587  2002.615017
# std     1578.077438     8.680141
# min        1.000000  1976.000000
# 25%      216.000000  1998.000000
# 50%      571.000000  2004.000000
# 75%     1387.000000  2009.000000
# ...

# %%
data.describe(include = 'all')
# Out:
#             movie_id        budget   popularity       revenue   title  \
# count    1465.000000  1.465000e+03  1465.000000  1.465000e+03    1465
# unique           NaN           NaN          NaN           NaN    1465
# top              NaN           NaN          NaN           NaN  Avatar
# freq             NaN           NaN          NaN           NaN       1
# mean    45225.191126  4.802295e+07    30.855973  1.432539e+08     NaN
# std      1189.096396  4.935541e+07    34.845214  2.064918e+08     NaN
# min     43597.000000  0.000000e+00     0.000000  0.000000e+00     NaN
# 25%     44236.000000  1.400000e+07    11.000000  1.738013e+07     NaN
# 50%     45022.000000  3.300000e+07    23.000000  7.578164e+07     NaN
# 75%     45990.000000  6.600000e+07    41.000000  1.792469e+08     NaN
# max     48395.000000  3.800000e+08   724.000000  2.787965e+09     NaN
#
#         vote_average    vote_count         year month     day  \
# count    1465.000000   1465.000000  1465.000000  1465    1465
# ...

# %%
data['revenue'] = data['revenue'] /1000000

# %%
data
# Out:
#       movie_id     budget  popularity      revenue  \
# 0        43597  237000000         150  2787.965087
# 1        43622  200000000         100  1845.034188
# 2        43876  100000000         101   520.000000
# 3        43879  115000000          38   378.882411
# 4        44184   70000000          24    90.000098
# ...        ...        ...         ...          ...
# 1460     46859          0          14    25.288872
# 1461     47023    6500000          11    13.368437
# 1462     47524    3000000           5     0.000000
# 1463     47962          0           0     0.000000
# 1464     48229     250000           1     4.186931
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
data['revenue'] = data['revenue'].round(2) #Round-off to 2 decimals

# %%
data
# Out:
#       movie_id     budget  popularity  revenue                       title  \
# 0        43597  237000000         150  2787.97                      Avatar
# 1        43622  200000000         100  1845.03                     Titanic
# 2        43876  100000000         101   520.00  Terminator 2: Judgment Day
# 3        43879  115000000          38   378.88                   True Lies
# 4        44184   70000000          24    90.00                   The Abyss
# ...        ...        ...         ...      ...                         ...
# 1460     46859          0          14    25.29                 Enough Said
# 1461     47023    6500000          11    13.37          Friends with Money
# 1462     47524    3000000           5     0.00                 Please Give
# 1463     47962          0           0     0.00         Walking and Talking
# 1464     48229     250000           1     4.19            Lovely & Amazing
#
# ...

# %%
data.rename(columns= {'revenue':'revenue(in Millions)'}, inplace = True)

# %%
data.rename(columns= {'budget(in Millions)':'Budget'}, inplace = True)

# %%
data
# Out:
#       movie_id     Budget  popularity  revenue(in Millions)  \
# 0        43597  237000000         150               2787.97
# 1        43622  200000000         100               1845.03
# 2        43876  100000000         101                520.00
# 3        43879  115000000          38                378.88
# 4        44184   70000000          24                 90.00
# ...        ...        ...         ...                   ...
# 1460     46859          0          14                 25.29
# 1461     47023    6500000          11                 13.37
# 1462     47524    3000000           5                  0.00
# 1463     47962          0           0                  0.00
# 1464     48229     250000           1                  4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              1465 non-null   int64
#  1   Budget                1465 non-null   int64
#  2   popularity            1465 non-null   int64
#  3   revenue(in Millions)  1465 non-null   float64
#  4   title                 1465 non-null   object
#  5   vote_average          1465 non-null   float64
#  6   vote_count            1465 non-null   int64
#  7   year                  1465 non-null   int64
#  8   month                 1465 non-null   object
#  9   day                   1465 non-null   object
#  10  director_name         1465 non-null   object
#  11  gender                1341 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 148.8+ KB

# %%
data['vote_average'] > 7 # This is a mask . Studied in Numpy
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data[data['vote_average'] > 7 ]
# Out:
#       movie_id     Budget  popularity  revenue(in Millions)  \
# 0        43597  237000000         150               2787.97
# 1        43622  200000000         100               1845.03
# 2        43876  100000000         101                520.00
# 4        44184   70000000          24                 90.00
# 5        46000   18500000          67                183.32
# ...        ...        ...         ...                   ...
# 1424     47488    4000000          11                 35.56
# 1426     48310     160000           3                  6.71
# 1433     46168   11500000          15                 23.24
# 1438     47597          0          11                  0.00
# 1441     47232    5000000          35                  8.20
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# ...

# %%
data.loc[data['vote_average'] > 7 , ['title', 'director_name']]
# Out:
#                            title  director_name
# 0                         Avatar  James Cameron
# 1                        Titanic  James Cameron
# 2     Terminator 2: Judgment Day  James Cameron
# 4                      The Abyss  James Cameron
# 5                         Aliens  James Cameron
# ...                          ...            ...
# 1424       Bowling for Columbine  Michael Moore
# 1426                  Roger & Me  Michael Moore
# 1433      The Remains of the Day    James Ivory
# 1438                     Maurice    James Ivory
# 1441               The Machinist  Brad Anderson
#
# [301 rows x 2 columns]

# %%
data.loc[(data["vote_average"]>7) & (data["year"]>=2015)]
# Out:
#      movie_id     Budget  popularity  revenue(in Millions)  \
# 93      43867  108000000         167                630.16
# 166     43641  190000000         102               1506.25
# 201     44784   40000000          48                165.48
# 361     43724  150000000         434                378.86
# 465     43773  135000000         100                532.95
# 512     44128   75000000          48                108.15
# 639     45301   28000000          57                133.35
# 649     44281   44000000          68                155.76
# 766     44770   35000000          53                194.56
# 818     47181    5000000          22                 24.80
# 853     45293   28000000          61                201.63
# 861     45194   30000000          65                 91.71
#
#                        title  vote_average  vote_count  year month        day  \
# 93               The Martian           7.6        7268  2015   Sep  Wednesday
# ...

# %%
data.loc[(data['day']== 'Wednesday') | (data['day']== 'Thursday') , ['title', 'year', 'day']]
# Out:
#                     title  year        day
# 0                  Avatar  2009   Thursday
# 3               True Lies  1994   Thursday
# 4               The Abyss  1989  Wednesday
# 9         The Lone Ranger  2013  Wednesday
# 10                  Rango  2011  Wednesday
# ...                   ...   ...        ...
# 1453   Dying of the Light  2014   Thursday
# 1456               Saw IV  2007   Thursday
# 1460          Enough Said  2013  Wednesday
# 1461   Friends with Money  2006   Thursday
# 1463  Walking and Talking  1996  Wednesday
#
# [553 rows x 3 columns]

# %%
data.sort_values(by = ['popularity'],ascending = False).head(5) # Top 5 popular movies
# Out:
#      movie_id     Budget  popularity  revenue(in Millions)  \
# 23      43692  165000000         724                675.12
# 361     43724  150000000         434                378.86
# 11      43796  140000000         271                655.01
# 315     43797  125000000         206                752.10
# 22      43662  185000000         187               1004.56
#
#                                                  title  vote_average  \
# 23                                        Interstellar           8.1
# 361                                 Mad Max: Fury Road           7.2
# 11   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 315              The Hunger Games: Mockingjay - Part 1           6.6
# 22                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 23        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# ...

# %%
data.loc[data['director_name'] == 'Christopher Nolan'] # Movies directed by Director 'Christopher Nolan'
# Out:
#     movie_id     Budget  popularity  revenue(in Millions)  \
# 21     43600  250000000         112               1084.94
# 22     43662  185000000         187               1004.56
# 23     43692  165000000         724                675.12
# 24     43693  160000000         167                825.53
# 25     43716  150000000         115                374.22
# 26     44630   46000000          41                113.71
# 27     44793   40000000          74                109.68
# 28     47170    9000000          60                 39.72
#
#                     title  vote_average  vote_count  year month        day  \
# 21  The Dark Knight Rises           7.6        9106  2012   Jul     Monday
# 22        The Dark Knight           8.2       12002  2008   Jul  Wednesday
# 23           Interstellar           8.1       10867  2014   Nov  Wednesday
# 24              Inception           8.1       13752  2010   Jul  Wednesday
# ...

# %%
data.loc[data['director_name'] == 'Christopher Nolan'].sort_values(by = ['popularity'], ascending = False) 
#Above result in sorted order
# Out:
#     movie_id     Budget  popularity  revenue(in Millions)  \
# 23     43692  165000000         724                675.12
# 22     43662  185000000         187               1004.56
# 24     43693  160000000         167                825.53
# 25     43716  150000000         115                374.22
# 21     43600  250000000         112               1084.94
# 27     44793   40000000          74                109.68
# 28     47170    9000000          60                 39.72
# 26     44630   46000000          41                113.71
#
#                     title  vote_average  vote_count  year month        day  \
# 23           Interstellar           8.1       10867  2014   Nov  Wednesday
# 22        The Dark Knight           8.2       12002  2008   Jul  Wednesday
# 24              Inception           8.1       13752  2010   Jul  Wednesday
# 25          Batman Begins           7.5        7359  2005   Jun     Friday
# ...

# %%
def myfunc(data):
    if data =="Male":
        return 1
    elif data=="Female":
        return 0
    else: 
        return np.nan

# %% [markdown]
# **Apply Method**

# %%
data['gender'] = data['gender'].apply(myfunc)

# %%
data
# Out:
#       movie_id     Budget  popularity  revenue(in Millions)  \
# 0        43597  237000000         150               2787.97
# 1        43622  200000000         100               1845.03
# 2        43876  100000000         101                520.00
# 3        43879  115000000          38                378.88
# 4        44184   70000000          24                 90.00
# ...        ...        ...         ...                   ...
# 1460     46859          0          14                 25.29
# 1461     47023    6500000          11                 13.37
# 1462     47524    3000000           5                  0.00
# 1463     47962          0           0                  0.00
# 1464     48229     250000           1                  4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# ...

# %%
data['Profit'] = (data['Budget']/100000) - data['revenue(in Millions)']
#Created a new column named Profit

# %%
data
# Out:
#       movie_id     Budget  popularity  revenue(in Millions)  \
# 0        43597  237000000         150               2787.97
# 1        43622  200000000         100               1845.03
# 2        43876  100000000         101                520.00
# 3        43879  115000000          38                378.88
# 4        44184   70000000          24                 90.00
# ...        ...        ...         ...                   ...
# 1460     46859          0          14                 25.29
# 1461     47023    6500000          11                 13.37
# 1462     47524    3000000           5                  0.00
# 1463     47962          0           0                  0.00
# 1464     48229     250000           1                  4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# ...

# %%
def profit_func(x):
    return x['Budget'] - x['revenue(in Millions)']

# %%
data['Profit_1'] = data[['Budget','revenue(in Millions)']] .apply(profit_func, axis =1)

# %%
data
# Out:
#       movie_id     Budget  popularity  revenue(in Millions)  \
# 0        43597  237000000         150               2787.97
# 1        43622  200000000         100               1845.03
# 2        43876  100000000         101                520.00
# 3        43879  115000000          38                378.88
# 4        44184   70000000          24                 90.00
# ...        ...        ...         ...                   ...
# 1460     46859          0          14                 25.29
# 1461     47023    6500000          11                 13.37
# 1462     47524    3000000           5                  0.00
# 1463     47962          0           0                  0.00
# 1464     48229     250000           1                  4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# ...

# %%
data[['Budget','revenue(in Millions)']].apply(np.sum, axis=1) # Apply function using universal function
#Axis = 1 is helping to calculate row wise operation
# Out:
# 0       2.370028e+08
# 1       2.000018e+08
# 2       1.000005e+08
# 3       1.150004e+08
# 4       7.000009e+07
#             ...
# 1460    2.529000e+01
# 1461    6.500013e+06
# 1462    3.000000e+06
# 1463    0.000000e+00
# 1464    2.500042e+05
# Length: 1465, dtype: float64

# %%
data[['Budget','revenue(in Millions)']].apply(np.sum, axis=0)
# Axis = 0 is helping to carryout column wise opeartion
# Out:
# Budget                  7.035362e+10
# revenue(in Millions)    2.098670e+05
# dtype: float64

# %%
data[['Budget','revenue(in Millions)']].apply(np.mean, axis=0)
# Out:
# Budget                  4.802295e+07
# revenue(in Millions)    1.432540e+02
# dtype: float64

# %%
data[['Budget','revenue(in Millions)']].apply(np.median, axis=0)
# Out:
# Budget                  33000000.00
# revenue(in Millions)          75.78
# dtype: float64
